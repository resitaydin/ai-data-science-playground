# %% [markdown]
# # LLM Evaluation Notebook
# This jupyter notebook provides instructions for evaluating a language model (LLM) on a variety of Turkish language benchmarks. For demonstration and efficiency purposes, a relatively small LLM is used. However, larger models can be tested using more powerful GPUs. For best results, it is recommended to run this notebook on Google Colab.

# %%
# !git clone https://github.com/malhajar17/lm-evaluation-harness_turkish.git
# Out:
# Cloning into 'lm-evaluation-harness_turkish'...
# remote: Enumerating objects: 29420, done.
# remote: Total 29420 (delta 0), reused 0 (delta 0), pack-reused 29420 (from 1)
# Receiving objects: 100% (29420/29420), 23.20 MiB | 19.93 MiB/s, done.
# Resolving deltas: 100% (19303/19303), done.

# %%
# %cd lm-evaluation-harness_turkish
# !pip3 install --upgrade pip
# !pip install -e .
# Out:
# [Errno 2] No such file or directory: 'lm-evaluation-harness_turkish'
# /content/lm-evaluation-harness_turkish
# ...
# Obtaining file:///content/lm-evaluation-harness_turkish
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.2-0.editable-py3-none-any.whl size=18004 sha256=fd8123c7ae8b74c27557f518c3fd7f5dac19d16d825f2d43755d5a53c9fd226b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6u2kwtr6/wheels/28/15/b1/719aca7167a33bb4e8e9e92ab704c14261081c136c341227f3
# Successfully built lm_eval
# ...
#   Attempting uninstall: lm_eval
#     Found existing installation: lm_eval 0.4.2
#     Uninstalling lm_eval-0.4.2:
#       Successfully uninstalled lm_eval-0.4.2
# ...

# %%
# !lm_eval --model hf \
    --model_args pretrained=facebook/opt-125m\
    --tasks mmlu_tr,arc_tr-v0.2,gsm8k_tr-v0.2,hellaswag_tr-v0.2,truthfulqa_v0.2,winogrande_tr-v0.2\
    --device cuda:0 \
    --batch_size 16
# Out:
# Streaming output truncated to the last 5000 lines.
# {'sentence': "Lindsey, Megan'dan bir adamın ona çıkma teklif ettiğinde nasıl nazikçe hayır diyebileceği konusunda tavsiye istiyor, çünkü _ duygular hakkında çok şey biliyor.", 'option1': 'Lindsey', 'option2': 'Megan', 'answer': '2'}
# {'sentence': "Cynthia matematik testinde Rebecca'dan çok daha iyi bir puan aldı. _ bunun için çalışmaya zaman ayırmadı.", 'option1': 'Cynthia', 'option2': 'Rebecca', 'answer': '2'}
# {'sentence': "Lindsey'ın gece _ dudak balmını sürmeyi unutması nedeniyle Elena'nın aksine koyu dudakları var.", 'option1': 'Lindsey', 'option2': 'Elena', 'answer': '1'}
# {'sentence': 'Manny kafes için yeni bir köpek yatağı aldığında, onu yerleştirmeye çalıştığında hayal kırıklığına uğradı. _ çok büyüktü.', 'option1': 'köpek yatağı', 'option2': 'kafes', 'answer': '1'}
# ...
